# %% [markdown]
# 1.	You have two DataFrames: students (with student IDs and names) and grades (with student IDs and exam scores). How would you combine them so that only students with recorded grades are included?

# %%
import pandas as pd

students=pd.DataFrame({
    'student_id':[1,2,3,4],
    'name':['Alice','Bob','Charlie','David']

    })
print(students)

grades=pd.DataFrame({
    'student_id':[1,2,4],
    'score':[85,90,88]
})
print(grades)

result=pd.merge(students,grades,on='student_id',how='inner')
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[157], line 3
#       1 import pandas as pd
# ----> 3 students=pd.DataFrame({
#       4     'student_id':[1,2,3,4],
#       5     'name':['Alice','Bob','Charlie','David']
#       6
#       7     })
#       8 print(students)
#      10 grades=pd.DataFrame({
#      11     'student_id':[1,2,4],
#      12     'score':[85,90,88]
#      13 })
#
# TypeError: 'dict' object is not callable

# %% [markdown]
# 2.	You need to merge employee and department DataFrames, ensuring all departments are shown even if no employees belong to them. What kind of join will you use?

# %%
import pandas as pd
employee_df=pd.DataFrame({
    'employee_id':[1,2],
    'name':["Alice","Bob"],
    "department_id":[10,20]
})
print(employee_df)
department_df=pd.DataFrame({
    'department_id':[10,20,30],
    'deparment_id':["HR","IT","Finance"]
})
print(department_df)
pd.merge(employee_df,department_df,on='department_id',how='right')
# Out:
#    employee_id   name  department_id
# 0            1  Alice             10
# 1            2    Bob             20
#    department_id deparment_id
# 0             10           HR
# 1             20           IT
# 2             30      Finance
#    employee_id   name  department_id deparment_id
# 0          1.0  Alice             10           HR
# 1          2.0    Bob             20           IT
# 2          NaN    NaN             30      Finance

# %% [markdown]
# 3.	A university has separate DataFrames for Spring, Summer, and Fall admissions. How would you combine them vertically into a single DataFrame?

# %%
import pandas as pd
spring_df=pd.DataFrame({'student':["Alice","Bob"],'season':["Sprinig","Spring"]})
summer_df=pd.DataFrame({'student':["Charlies"],"season":["Summer"]})
fall_df=pd.DataFrame({'student':["David","Eve"],"season":["Fall","Fall"]})

all_admissions=pd.concat([spring_df,summer_df,fall_df],axis=0,ignore_index=True)
print(all_admissions)
# Out:
#     student   season
# 0     Alice  Sprinig
# 1       Bob   Spring
# 2  Charlies   Summer
# 3     David     Fall
# 4       Eve     Fall

# %% [markdown]
# 4.	You’re merging two DataFrames but lose some rows from the first one. Which type of join might be causing this?

# %%
import pandas as pd

df1=pd.DataFrame({"id":[1,2,3],"name":["Alice","Bob","Charlie"]})
print(df1)
df2=pd.DataFrame({"id":[1,2],"score":[85,90]})
print(df2)
pd.merge(df1,df2,on="id",how="inner")
# Out:
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
#    id  score
# 0   1     85
# 1   2     90
#    id   name  score
# 0   1  Alice     85
# 1   2    Bob     90

# %% [markdown]
# 5.	A retail store wants to know the total sales per product category. Which Pandas operation would help you summarize this?

# %%
import pandas as pd
data=pd.DataFrame({
    'category':['Electronics','Clothing','Electronics','Clothing','Grocery'],
    "sales":[200,150,300,100,50]

})
total_sales=data.groupby('category')['sales'].sum()
print(total_sales)
# Out:
# category
# Clothing       250
# Electronics    500
# Grocery         50
# Name: sales, dtype: int64

# %% [markdown]
# 6.	You need to find the average rating given by each customer in a reviews dataset. How can groupby() help?

# %%
import pandas as pd
reviews=pd.DataFrame({
    "customer_id":[101,102,101,103,102,101],
    "rating":[4,5,3,4,4,5]
})
avg_rating=reviews.groupby('customer_id')['rating'].mean()
print(avg_rating)
# Out:
# customer_id
# 101    4.0
# 102    4.5
# 103    4.0
# Name: rating, dtype: float64

# %% [markdown]
# 7.	You're analyzing test scores and want to count how many students fall into each grade bracket (A, B, C). Which combo of operations is best suited?

# %%
import pandas as pd
scores=pd.DataFrame=({
    "student":['Alice','Bob','Charlie','David','Eve','Kazma'],
    'score':[92,76,88,65,54,40]
})

scores['grade']=pd.cut(
    scores['score'],
    bins=[0,59,69,79,89,100],
    labels=["F","D","C","B","A"]
)
grade_counts=scores['grade'].value_counts()
print(grade_counts)
# Out:
# F    2
# D    1
# C    1
# B    1
# A    1
# Name: count, dtype: int64

# %% [markdown]
# 8.	You have a dataset of continuous values like age, and you want to group people into age brackets (e.g., 0–18, 19–35). What technique will you use?

# %%
import pandas as pd

people=pd.DataFrame
({
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve','Fatima','komal'],
    'age': [40, 25, 36, 45, 60,7,8]
})

people["age_group"]=pd.cut(
    people['age'],
    bins=[0,18,35,50,100],
    labels=['0-18','19-35','36-50','51+']
)
print(people)
# Out:
# {'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Fatima', 'komal'], 'age': [40, 25, 36, 45, 60, 7, 8], 'age_group': ['36-50', '19-35', '36-50', '36-50', '51+', '0-18', '0-18']
# Categories (4, object): ['0-18' < '19-35' < '36-50' < '51+']}
# 0-18     2
# 19-35    1
# 36-50    3
# 51+      1
# Name: count, dtype: int64

# %% [markdown]
# 9.	A dataset contains temperatures in Celsius. You want to categorize them as 'Cold', 'Warm', or 'Hot'. Which method will you apply?

# %%
import pandas as pd

df=pd.DataFrame=({
    "temperature":[5,12,18,25,30,37]
})

df["temp_category"]=pd.cut(
    df["temperature"],
    bins=[-float('inf'),15,25,float('inf')],
    labels=['Cold','Warm','Hot']
)
print(df)
# Out:
# {'temperature': [5, 12, 18, 25, 30, 37], 'temp_category': ['Cold', 'Cold', 'Warm', 'Warm', 'Hot', 'Hot']
# Categories (3, object): ['Cold' < 'Warm' < 'Hot']}

# %% [markdown]
# 10.	You want to apply a 10% discount to all prices in a 'Price' column. Which operation will help you do this efficiently?

# %%
import pandas as pd

#Sample price data
df=pd.DataFrame
({
    'Product':['A','B','C'],
    'Price':[100,200,150]
})

#Apply 10% Discount

#df['Price'] = pd.to_numeric(df['Price'])
df['Discounted_Price'] = df['Price'] * 0.9
# df["Discounted_Price"]=df['Price'].astype(float)*0.9

print(df)
# Out:
# {'Product': ['A', 'B', 'C'], 'Price': array([100, 200, 150]), 'Discounted_Price': array([ 90., 180., 135.])}

# %% [markdown]
# 11.	You need to rename all column names to lowercase. How would you approach this using Pandas?

# %%
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Product': ['A', 'B', 'C'],
    'Price': [100, 200, 150],
    'Quantity': [10, 20, 15]
})

# Rename columns to lowercase
df.columns = df.columns.str.lower()

# Print column names
print(list(df.columns)[0])
# Out:
# product

# %% [markdown]
# 12.	After preprocessing a large dataset, you want to save it to a CSV file but without the index. How would you do that in Pandas?

# %%
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Product': ['A', 'B', 'C'],
    'Price': [100, 200, 150],
    'Quantity': [10, 20, 15]
})

# Save DataFrame to CSV without the index
df.to_csv('output.csv', index=False)

# %% [markdown]
# 13.	You want to visualize the distribution of a single numeric column such as "Income". Which Pandas plot would be ideal?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
df = pd.DataFrame({
    "Income": [50000, 60000, 55000, 70000, 80000, 75000, 95000, 120000, 110000, 130000]
})

# Plot the Histogram
df["Income"].plot(kind='hist', bins=10, edgecolor='black')

# Show the Plot
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 14.	You want to compare the monthly sales of two different products over a year. What kind of plot should you use?

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Sample DataFrame with monthly sales data for two products
df=pd.DataFrame
({
    "Month":['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
    'Product_A': [100, 120, 150, 180, 130, 140, 160, 170, 190, 200, 210, 220],
    'Product_B': [80, 90, 100, 110, 105, 115, 120, 125, 135, 140, 150, 160]
})

#Set Month as the index for better time based plotting
df.set_index('Month',inplace=True)

#Plot the sales for both products
df.plot(kind='line',figsize=(10,6))

#Customize the plot
plt.title("Monthly Sales")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[147], line 13
#       6 ({
#       7     "Month":['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
#       8     'Product_A': [100, 120, 150, 180, 130, 140, 160, 170, 190, 200, 210, 220],
#       9     'Product_B': [80, 90, 100, 110, 105, 115, 120, 125, 135, 140, 150, 160]
#      10 })
#      12 #Set Month as the index for better time based plotting
# ---> 13 df.set_index('Month',inplace=True)
#
# AttributeError: 'dict' object has no attribute 'set_index'

# %% [markdown]
# 15.	You’re analyzing student performance across subjects and want to see the relationship between math and science scores. Which Pandas plot type is appropriate?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
df = pd.DataFrame({
    'Math': [78, 85, 90, 95, 88],
    'Science': [80, 87, 92, 96, 89]
})

# Scatter plot
df.plot(kind='scatter', x='Math', y='Science')
plt.title('Math vs Science Scores')
plt.show()

# %% [markdown]
# 16.	You want to see both the histogram and KDE curve for customers' ages in one plot. Which Seaborn function should you use?

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#Sample : List of customer ages
ages=[22,25,30,35,40,22,25,28,34,38,45,50,29,31,33,36,39,41,43,48]

#Create Histogram with KDE
sns.histplot(ages,kde=True,bins=10,color='skyblue',edgecolor='black')


#Customize the plot
plt.title("Distribution of Customer Ages")
plt.xlabel("Age")
plt.ylabel("Frequncy/Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 17.	To visualize how two numerical variables (e.g., weight and height) relate and are distributed, which Seaborn plot combines both scatter and histograms?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Sample Data
df=sns.load_dataset("penguins")

#Create a joint plot
sns.jointplot(data=df,x="bill_length_mm",y="bill_depth_mm",kind="scatter")
plt.show()

# %% [markdown]
# 18.	You want to compare median income across three job categories. Which Seaborn plot gives you a distribution and median view?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Sample Data

df=sns.load_dataset("titanic")   #Replace with your dataset
sns.boxplot(x="class",y="fare",data=df)
plt.title("Fare Distribution by Class")
plt.xlabel("Class")
plt.ylabel("Fare")
plt.grid(True)
plt.show()

# %% [markdown]
# 19.	A survey collected gender-wise responses for four product preferences. Which plot best shows response counts by gender?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Product': ['A', 'A', 'B', 'B', 'C', 'C', 'D', 'D'],
    'Count': [30, 40, 20, 35, 25, 30, 15, 25]
}

df = pd.DataFrame(data)

# Pivot the data for plotting
pivot_df = df.pivot(index='Product', columns='Gender', values='Count')

# Plot
pivot_df.plot(kind='bar', figsize=(8, 6))
plt.title('Product Preferences by Gender')
plt.xlabel('Product')
plt.ylabel('Response Count')
plt.xticks(rotation=0)
plt.legend(title='Gender')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# 20.	You’re analyzing a correlation matrix of features in a dataset. How can you visualize all pairwise correlations clearly using color intensity?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1],
    'C': [2, 3, 4, 5, 6],
    'D': [5, 6, 7, 8, 9]
})

# Compute correlation matrix
corr = df.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title('Feature Correlation Heatmap')
plt.show()
